# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stat

# %%
x=np.arange(-100,100)
y=x**2
plt.plot(x,y)
print("Correlation: {:.2f}".format(stat.pearsonr(x,y)[0]))
plt.show()
# Out:
# Correlation: -0.02
